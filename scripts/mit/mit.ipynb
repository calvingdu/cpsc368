# %% [markdown]
# # CPSC 368 – Group 4: YouTube Data Collection
# ## Phase 3 – Data Collection from MIT datasets
#
# This notebook collects MIT data and refines into CSV files that can then be uploaded to SQL Oracle

# %%
import pandas as pd
import os

# %%
df_1976_2020 = pd.read_csv("../../source_data/mit/1976-2020-president.csv")
df_2024 = pd.read_csv("../../source_data/mit/2024-president-state.csv")
df_2020 = df_1976_2020[df_1976_2020["year"] == 2020].reset_index(drop=True)

print("2020:")
print(df_2020.shape[0], "rows")
display(df_2020.head())
print("2024:")
print(df_2024.shape[0], "rows")
display(df_2024.head())
# Out:
# 2020:
# 547 rows
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 1  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 2  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 3  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 4  2020   ALASKA       AK           2         94        81  US PRESIDENT
#
#              candidate party_detailed writein  candidatevotes  totalvotes  \
# 0  BIDEN, JOSEPH R. JR       DEMOCRAT   False          849624     2323282
# 1     TRUMP, DONALD J.     REPUBLICAN   False         1441170     2323282
# 2        JORGENSEN, JO    LIBERTARIAN   False           25176     2323282
# 3                  NaN            NaN    True            7312     2323282
# 4  BIDEN, JOSEPH R. JR       DEMOCRAT   False          153778      359530
#
#     version  notes party_simplified
# 0  20210113    NaN         DEMOCRAT
# 1  20210113    NaN       REPUBLICAN
# 2  20210113    NaN      LIBERTARIAN
# 3  20210113    NaN            OTHER
# 4  20210113    NaN         DEMOCRAT
# 2024:
# 535 rows
#    year   state state_po  state_fips  state_ic        office  \
# 0  2024  ALASKA       AK           2      81.0  US PRESIDENT
# 1  2024  ALASKA       AK           2      81.0  US PRESIDENT
# 2  2024  ALASKA       AK           2      81.0  US PRESIDENT
# 3  2024  ALASKA       AK           2      81.0  US PRESIDENT
# 4  2024  ALASKA       AK           2      81.0  US PRESIDENT
#
#                candidate       party_detailed party_simplified  writein  \
# 0      HARRIS, KAMALA D.             DEMOCRAT         DEMOCRAT    False
# 1  KENNEDY, ROBERT F. JR       NON-AFFILIATED            OTHER    False
# 2          OLIVER, CHASE          LIBERTARIAN      LIBERTARIAN    False
# 3          SONSKI, PETER  AMERICAN SOLIDARITY            OTHER    False
# 4            STEIN, JILL       NON-AFFILIATED            OTHER    False
#
#     mode   votes  totalvotes stage  special  unofficial     version
# 0  TOTAL  140026      338177   GEN    False       False  2025-11-20
# 1  TOTAL    5670      338177   GEN    False       False  2025-11-20
# 2  TOTAL    3040      338177   GEN    False       False  2025-11-20
# 3  TOTAL     702      338177   GEN    False       False  2025-11-20
# 4  TOTAL    2342      338177   GEN    False       False  2025-11-20

# %%
df_2020.rename(columns={"candidatevotes": "votes"}, inplace=True)
common_cols = df_2020.columns.intersection(df_2024.columns)
print("Common columns:", list(common_cols))



df = pd.concat([df_2020, df_2024], ignore_index=True)[common_cols]
print(df.shape[0], "rows total amongst 2020, and 2024 datasets")
display(df.head())
display(df["year"].unique())

# Removing all parties except DEM and REP, and all rows with missing values in the 'candidate' column
df = df[df["party_simplified"].isin(["DEMOCRAT", "REPUBLICAN"])]
df = df.dropna(subset=["candidate"])
print(
    df.shape[0],
    "rows after filtering for DEM and REP parties and dropping rows with missing candidate names",
)
display(df.head())
# Out:
# Common columns: ['year', 'state', 'state_po', 'state_fips', 'state_ic', 'office', 'candidate', 'party_detailed', 'writein', 'votes', 'totalvotes', 'version', 'party_simplified']
# 1082 rows total amongst 2020, and 2024 datasets
#    year    state state_po  state_fips  state_ic        office  \
# 0  2020  ALABAMA       AL           1      41.0  US PRESIDENT
# 1  2020  ALABAMA       AL           1      41.0  US PRESIDENT
# 2  2020  ALABAMA       AL           1      41.0  US PRESIDENT
# 3  2020  ALABAMA       AL           1      41.0  US PRESIDENT
# 4  2020   ALASKA       AK           2      81.0  US PRESIDENT
#
#              candidate party_detailed writein    votes  totalvotes   version  \
# 0  BIDEN, JOSEPH R. JR       DEMOCRAT   False   849624     2323282  20210113
# 1     TRUMP, DONALD J.     REPUBLICAN   False  1441170     2323282  20210113
# 2        JORGENSEN, JO    LIBERTARIAN   False    25176     2323282  20210113
# 3                  NaN            NaN    True     7312     2323282  20210113
# 4  BIDEN, JOSEPH R. JR       DEMOCRAT   False   153778      359530  20210113
#
#   party_simplified
# 0         DEMOCRAT
# 1       REPUBLICAN
# 2      LIBERTARIAN
# 3            OTHER
# 4         DEMOCRAT
# array([2020, 2024])
# 204 rows after filtering for DEM and REP parties and dropping rows with missing candidate names
#     year    state state_po  state_fips  state_ic        office  \
# 0   2020  ALABAMA       AL           1      41.0  US PRESIDENT
# 1   2020  ALABAMA       AL           1      41.0  US PRESIDENT
# 4   2020   ALASKA       AK           2      81.0  US PRESIDENT
# 5   2020   ALASKA       AK           2      81.0  US PRESIDENT
# 12  2020  ARIZONA       AZ           4      61.0  US PRESIDENT
#
#               candidate party_detailed writein    votes  totalvotes   version  \
# 0   BIDEN, JOSEPH R. JR       DEMOCRAT   False   849624     2323282  20210113
# 1      TRUMP, DONALD J.     REPUBLICAN   False  1441170     2323282  20210113
# 4   BIDEN, JOSEPH R. JR       DEMOCRAT   False   153778      359530  20210113
# 5      TRUMP, DONALD J.     REPUBLICAN   False   189951      359530  20210113
# 12  BIDEN, JOSEPH R. JR       DEMOCRAT   False  1672143     3387326  20210113
#
#    party_simplified
# 0          DEMOCRAT
# 1        REPUBLICAN
# 4          DEMOCRAT
# 5        REPUBLICAN
# 12         DEMOCRAT

# %% [markdown]
# ### Data Quality Testing

# %%
assert df["office"].nunique() == 1 and df["office"].unique()[0] == "US PRESIDENT"
assert df["state"].nunique() == 51

# %% [markdown]
# ### Upload

# %%
os.makedirs("../../cleaned_data/mit", exist_ok=True)
display(df.head())
df.rename(columns={"party_simplified": "party"}, inplace=True)
final_df = df[["year", "state", "state_po", "candidate", "party", "votes", "totalvotes"]]
display(final_df.head())
final_df.to_csv(
    "../../cleaned_data/mit/mit_presidential_election_data.csv", index=False
)
# Out:
#     year    state state_po  state_fips  state_ic        office  \
# 0   2020  ALABAMA       AL           1      41.0  US PRESIDENT
# 1   2020  ALABAMA       AL           1      41.0  US PRESIDENT
# 4   2020   ALASKA       AK           2      81.0  US PRESIDENT
# 5   2020   ALASKA       AK           2      81.0  US PRESIDENT
# 12  2020  ARIZONA       AZ           4      61.0  US PRESIDENT
#
#               candidate party_detailed writein    votes  totalvotes   version  \
# 0   BIDEN, JOSEPH R. JR       DEMOCRAT   False   849624     2323282  20210113
# 1      TRUMP, DONALD J.     REPUBLICAN   False  1441170     2323282  20210113
# 4   BIDEN, JOSEPH R. JR       DEMOCRAT   False   153778      359530  20210113
# 5      TRUMP, DONALD J.     REPUBLICAN   False   189951      359530  20210113
# 12  BIDEN, JOSEPH R. JR       DEMOCRAT   False  1672143     3387326  20210113
#
#    party_simplified
# 0          DEMOCRAT
# 1        REPUBLICAN
# 4          DEMOCRAT
# 5        REPUBLICAN
# 12         DEMOCRAT
#     year    state state_po            candidate       party    votes  \
# 0   2020  ALABAMA       AL  BIDEN, JOSEPH R. JR    DEMOCRAT   849624
# 1   2020  ALABAMA       AL     TRUMP, DONALD J.  REPUBLICAN  1441170
# 4   2020   ALASKA       AK  BIDEN, JOSEPH R. JR    DEMOCRAT   153778
# 5   2020   ALASKA       AK     TRUMP, DONALD J.  REPUBLICAN   189951
# 12  2020  ARIZONA       AZ  BIDEN, JOSEPH R. JR    DEMOCRAT  1672143
#
#     totalvotes
# 0      2323282
# 1      2323282
# 4       359530
# 5       359530
# 12     3387326
