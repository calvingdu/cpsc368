# %% [markdown]
# # CPSC 368 – Group 4
# ## Phase 4 – Creating JSON files from MIT datasets
# This notebook creates JSON files from cleaned MIT csv file.

# %%
import csv
import json
import pandas as pd

# %%
# 1. create JSON of MIT data
mit = pd.read_csv('mit_presidential_election_data.csv')

# 2. Convert to JSON 
mit_json = mit.to_json('mit_presidential_election_data.json', orient='records', indent=4)

print("done")
# Out:
# done
